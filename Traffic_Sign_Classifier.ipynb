# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Deep-Learning-Project:-Build-a-Traffic-Sign-Recognition-Classifier" data-toc-modified-id="Deep-Learning-Project:-Build-a-Traffic-Sign-Recognition-Classifier-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Deep Learning Project: Build a Traffic Sign Recognition Classifier</a></span><ul class="toc-item"><li><span><a href="#Import-Tensorflow-and-display-some-diagnostic-messages" data-toc-modified-id="Import-Tensorflow-and-display-some-diagnostic-messages-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import Tensorflow and display some diagnostic messages</a></span></li></ul></li><li><span><a href="#Step-0:-Load-The-Data" data-toc-modified-id="Step-0:-Load-The-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Step 0: Load The Data</a></span></li><li><span><a href="#Step-1:-Dataset-Summary-&amp;-Exploration" data-toc-modified-id="Step-1:-Dataset-Summary-&amp;-Exploration-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Step 1: Dataset Summary &amp; Exploration</a></span><ul class="toc-item"><li><span><a href="#Provide-a-Basic-Summary-of-the-Data-Set-Using-Python,-Numpy-and/or-Pandas" data-toc-modified-id="Provide-a-Basic-Summary-of-the-Data-Set-Using-Python,-Numpy-and/or-Pandas-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas</a></span></li><li><span><a href="#Include-an-exploratory-visualization-of-the-dataset" data-toc-modified-id="Include-an-exploratory-visualization-of-the-dataset-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Include an exploratory visualization of the dataset</a></span></li></ul></li><li><span><a href="#Step-2:-Design-and-Test-a-Model-Architecture" data-toc-modified-id="Step-2:-Design-and-Test-a-Model-Architecture-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Step 2: Design and Test a Model Architecture</a></span><ul class="toc-item"><li><span><a href="#Pre-process-the-Data-Set-(normalization,-grayscale,-etc.)" data-toc-modified-id="Pre-process-the-Data-Set-(normalization,-grayscale,-etc.)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Pre-process the Data Set (normalization, grayscale, etc.)</a></span><ul class="toc-item"><li><span><a href="#Examples-of-augmented-images-(without-normalization)" data-toc-modified-id="Examples-of-augmented-images-(without-normalization)-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Examples of augmented images (without normalization)</a></span></li></ul></li><li><span><a href="#Define-Model-Architectures" data-toc-modified-id="Define-Model-Architectures-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Define Model Architectures</a></span><ul class="toc-item"><li><span><a href="#This-is-equivalent-to-the-model_config-configuration-file" data-toc-modified-id="This-is-equivalent-to-the-model_config-configuration-file-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>This is equivalent to the model_config configuration file</a></span></li><li><span><a href="#Architecture-1" data-toc-modified-id="Architecture-1-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Architecture 1</a></span></li><li><span><a href="#Architecture-1-+-Dropout" data-toc-modified-id="Architecture-1-+-Dropout-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Architecture 1 + Dropout</a></span></li><li><span><a href="#Architecture-2" data-toc-modified-id="Architecture-2-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Architecture 2</a></span></li><li><span><a href="#Architecture-2-+-Dropout" data-toc-modified-id="Architecture-2-+-Dropout-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Architecture 2 + Dropout</a></span></li><li><span><a href="#Architecture-3" data-toc-modified-id="Architecture-3-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Architecture 3</a></span></li><li><span><a href="#Architecture-3-+-Dropout" data-toc-modified-id="Architecture-3-+-Dropout-4.2.7"><span class="toc-item-num">4.2.7&nbsp;&nbsp;</span>Architecture 3 + Dropout</a></span></li><li><span><a href="#Architecture-A4" data-toc-modified-id="Architecture-A4-4.2.8"><span class="toc-item-num">4.2.8&nbsp;&nbsp;</span>Architecture A4</a></span></li><li><span><a href="#Architecture-A4-+-Dropout-+-Image-Augmentation" data-toc-modified-id="Architecture-A4-+-Dropout-+-Image-Augmentation-4.2.9"><span class="toc-item-num">4.2.9&nbsp;&nbsp;</span>Architecture A4 + Dropout + Image Augmentation</a></span></li><li><span><a href="#Architecture-A4,-A5,-A6,-A7" data-toc-modified-id="Architecture-A4,-A5,-A6,-A7-4.2.10"><span class="toc-item-num">4.2.10&nbsp;&nbsp;</span>Architecture A4, A5, A6, A7</a></span></li></ul></li><li><span><a href="#Train,-Validate-and-Test-the-Model" data-toc-modified-id="Train,-Validate-and-Test-the-Model-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Train, Validate and Test the Model</a></span></li><li><span><a href="#Run-Training" data-toc-modified-id="Run-Training-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Run Training</a></span><ul class="toc-item"><li><span><a href="#Setup-Preprocessing-Pipeline" data-toc-modified-id="Setup-Preprocessing-Pipeline-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Setup Preprocessing Pipeline</a></span></li><li><span><a href="#Display-Number-of-Batches-per-Epoch-(BPE)-based-on-batch-size" data-toc-modified-id="Display-Number-of-Batches-per-Epoch-(BPE)-based-on-batch-size-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Display Number of Batches per Epoch (BPE) based on batch size</a></span></li><li><span><a href="#Load-model_config.cfg-file" data-toc-modified-id="Load-model_config.cfg-file-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Load <code>model_config.cfg</code> file</a></span></li><li><span><a href="#Load-Model-Training-Results-file-(to-get-model-checkpoint-file)" data-toc-modified-id="Load-Model-Training-Results-file-(to-get-model-checkpoint-file)-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Load Model Training Results file (to get model checkpoint file)</a></span></li><li><span><a href="#run_model_training()" data-toc-modified-id="run_model_training()-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span><code>run_model_training()</code></a></span></li><li><span><a href="#inspect-Results" data-toc-modified-id="inspect-Results-4.4.6"><span class="toc-item-num">4.4.6&nbsp;&nbsp;</span>inspect Results</a></span></li><li><span><a href="#Training-Results" data-toc-modified-id="Training-Results-4.4.7"><span class="toc-item-num">4.4.7&nbsp;&nbsp;</span>Training Results</a></span></li></ul></li><li><span><a href="#Run-Test" data-toc-modified-id="Run-Test-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Run Test</a></span><ul class="toc-item"><li><span><a href="#Setup-Test-Dataset-Preprocessing-data-flow" data-toc-modified-id="Setup-Test-Dataset-Preprocessing-data-flow-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Setup Test Dataset Preprocessing data flow</a></span></li><li><span><a href="#Setup-Test-Pipeline" data-toc-modified-id="Setup-Test-Pipeline-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Setup Test Pipeline</a></span></li></ul></li></ul></li><li><span><a href="#Step-3:-Test-a-Model-on-New-Images" data-toc-modified-id="Step-3:-Test-a-Model-on-New-Images-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Step 3: Test a Model on New Images</a></span><ul class="toc-item"><li><span><a href="#Load-and-Output-the-Images" data-toc-modified-id="Load-and-Output-the-Images-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Load and Output the Images</a></span></li><li><span><a href="#Predict-the-Sign-Type-for-Each-Image" data-toc-modified-id="Predict-the-Sign-Type-for-Each-Image-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Predict the Sign Type for Each Image</a></span></li><li><span><a href="#Analyze-Performance" data-toc-modified-id="Analyze-Performance-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Analyze Performance</a></span></li><li><span><a href="#Output-Top-5-Softmax-Probabilities-For-Each-Image-Found-on-the-Web" data-toc-modified-id="Output-Top-5-Softmax-Probabilities-For-Each-Image-Found-on-the-Web-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Output Top 5 Softmax Probabilities For Each Image Found on the Web</a></span></li></ul></li><li><span><a href="#Project-Writeup" data-toc-modified-id="Project-Writeup-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Project Writeup</a></span></li><li><span><a href="#Step-4-(Optional):-Visualize-the-Neural-Network's-State-with-Test-Images" data-toc-modified-id="Step-4-(Optional):-Visualize-the-Neural-Network's-State-with-Test-Images-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Step 4 (Optional): Visualize the Neural Network's State with Test Images</a></span></li></ul></div>

# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %%
# Load pickled data
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import math
import time
import configparser
import pprint
import matplotlib.pyplot as plt
from datetime import datetime
from scipy import stats
from sklearn.utils import shuffle
from tqdm import tqdm, trange
from collections import defaultdict
from common.utils import *

# %load_ext autoreload
# %autoreload 2
# Visualizations will be shown in the notebook.
# %matplotlib inline

pp = pprint.PrettyPrinter(indent=2, width=130)

# %% [markdown]
# ### Import Tensorflow and display some diagnostic messages

# %%
# 0 = all messages are logged (default behavior)
# 1 = INFO messages are not printed
# 2 = INFO and WARNING messages are not printed
# 3 = INFO, WARNING, and ERROR messages are not printed

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
# import tensorflow as tf
import tensorflow.compat.v1 as tf
import tensorflow.keras.preprocessing as kp
# tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# print(tf.logging.get_verbosity())
from tensorflow.python.client import device_lib
device_list = device_lib.list_local_devices()

print(' Tensorflow Version      : ', tf.__version__)
print(' Built with CUDA support : ', tf.test.is_built_with_cuda())
print(' GPU available           : ', tf.test.is_gpu_available())
print(' List of GPU Devices     : ', tf.config.list_physical_devices('GPU'))
# print(device_list)
# print(type(device_list), len(device_list), type(device_list[0]))
print()
print(' Device Name           Type           Memory Limit    Description')
print(' -----------------     -------        ------------    ---------------')
for i,dev in enumerate(device_list):
    print(' {:20s}  {:10s}  {:15d}    {}'.format(dev.name, dev.device_type, dev.memory_limit, dev.physical_device_desc))
print()

tf.disable_v2_behavior()
# Out:
#  Tensorflow Version      :  2.3.1
#  Built with CUDA support :  True
# WARNING:tensorflow:From <ipython-input-2-38b80a563be9>:17: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
#  GPU available           :  True
#  List of GPU Devices     :  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
#  Device Name           Type           Memory Limit    Description
#  -----------------     -------        ------------    ---------------
#  /device:CPU:0         CPU               268435456
#  /device:XLA_CPU:0     XLA_CPU         17179869184    device: XLA_CPU device
#  /device:GPU:0         GPU              2241052672    device: 0, name: GeForce GTX 970M, pci bus id: 0000:01:00.0, compute capability: 5.2
#  /device:XLA_GPU:0     XLA_GPU         17179869184    device: XLA_GPU device
#
# ...

# %% [markdown]
# ## Step 0: Load The Data

# %%
# TODO: Fill this in based on where you saved the training and testing data
# F:\MLDatasets\traffic-signs-data

# del X_train, y_train, X_valid, y_valid

training_file   = 'F:/MLDatasets/traffic-signs-data/train.p'
validation_file = 'F:/MLDatasets/traffic-signs-data/valid.p'
testing_file    = 'F:/MLDatasets/traffic-signs-data/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test   = test['features'], test['labels']

# %% [markdown]
# ## Step 1: Dataset Summary & Exploration

# %% [markdown]
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
# ---
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results.
#
# For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results

# Number of training/validation/testing examples
n_train = train['features'].shape[0]
n_validation = valid['features'].shape[0]
n_test = test['labels'].shape[0]

# What's the shape of an traffic sign image?
image_shape = train['features'].shape[1:]

# How many unique classes/labels there are in the dataset.
y_df = pd.DataFrame(train['labels'])
y_ids = sorted(pd.unique(y_df[0]).tolist())
# print(' Number of unique labels : {} \n Labels: {} '.format(len(y_ids), y_ids))
n_classes = len(y_ids)

print(' Training dataset shapes............ features: {}    labels: {}'.format(train['features'].shape, train['labels'].shape))
print(' Validation dataset shapes ......... features: {}    labels: {}'.format(valid['features'].shape, valid['labels'].shape))
print(' Testing dataset shapes ............ features: {}    labels: {}'.format(test['features'].shape, test['labels'].shape))
print(' Training dictionary keys ..........',list(train.keys()))
print('\n Training images original size samples   : \n',train['sizes'][:10])
print('\n Training Bounding box coordinate samples: \n',train['coords'][:10])

print()
print(" Number of training examples ....... ", n_train)
print(" Number of validation examples ..... ", n_validation)
print(" Number of testing examples ........ ", n_test)
print(" Image data shape .................. ", image_shape)
print(" Number of classes ................. ", n_classes)

signnames_csv = pd.read_csv('signnames.csv')
signnames = signnames_csv["SignName"].str.strip().to_dict()
sign_keys = signnames.keys()
sign_len = len(sign_keys)
half_len = math.ceil( sign_len / 2 )
signnames_list = ['{:2d}-{:s}'.format(i,v[:30]) for i,v in signnames.items()]
print()
print('  Id    Sign description               \t\t\t\t  Id    Sign description               ')
print(' ----   -------------------------------\t\t\t\t ----   -------------------------------')


for i in range(0,half_len,1):
    print('  {:2d}    {:45s}'.format(i,signnames[i]), end = '')
    if (i+half_len) < sign_len:
        print('\t\t  {:2d}    {:45s}'.format(i+half_len,signnames[i+half_len]))
    else:
        print('\t\t ','-'*20)
        
print('\n signnames_list ')
print('----------------')
pp.pprint(signnames_list)
# Out:
#  Training dataset shapes............ features: (34799, 32, 32, 3)    labels: (34799,)
#  Validation dataset shapes ......... features: (4410, 32, 32, 3)    labels: (4410,)
#  Testing dataset shapes ............ features: (12630, 32, 32, 3)    labels: (12630,)
#  Training dictionary keys .......... ['coords', 'labels', 'features', 'sizes']
#
#  Training images original size samples   :
#  [[26 25]
#  [27 27]
#  [27 28]
#  [27 28]
#  [29 29]
#  [30 28]
#  [31 30]
#  [30 30]
#  [32 30]
#  [32 31]]
#
#  Training Bounding box coordinate samples:
#  [[ 6  5 21 20]
#  [ 6  6 22 22]
#  [ 5  6 22 23]
#  [ 5  6 22 23]
#  [ 5  6 23 23]
#  [ 6  5 25 23]
#  [ 6  5 25 25]
#  [ 5  5 25 25]
#  [ 6  5 26 25]
#  [ 6  5 27 26]]
#
#  Number of training examples .......  34799
#  Number of validation examples .....  4410
#  Number of testing examples ........  12630
#  Image data shape ..................  (32, 32, 3)
#  Number of classes .................  43
#
# ...

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.

# %%
display_random_images(X_train, y_train, signnames,  ticks = True, grid = False, h_pad = 0, w_pad = 1)

# %%
img_lst = [6012, 27728, 24108, 30119, 6527, 16037,7090,11251, 12732, 29084, 245, 24596, 23871, 26470,22588, 15767]
img_lst2= [6012, 27780, 32215, 3201, 34000, 28127, 14743, 28209,16969]
# display_images(X_train, y_train, signnames, disp_img_ids = img_lst,ticks = True, grid = False, h_pad = 0, w_pad = 1)
display_images(X_train[img_lst], y_train[img_lst], signnames,ticks = True, grid = False, h_pad = 0, w_pad = 1)

# %%
print(X_train[28127].min(), X_train[28127].mean(), X_train[28127].max() )
# Out:
# 13 23.623046875 50

# %%
display_image(X_train, y_train, signnames, 28127)
display_image(X_train, y_train, signnames, 16969)
display_image(X_train, y_train, signnames, 26470)
display_image(X_train, y_train, signnames, 8143)
display_image(X_train, y_train, signnames, 27728)

# %%
display_label_distribution(y_train, signnames)

# %% [markdown]
# ## Step 2: Design and Test a Model Architecture

# %% [markdown]
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
### Preprocess the data here. It is required to normalize the data. Other preprocessing steps could include 
### converting to grayscale, etc.
### Feel free to use as many code cells as needed.

# %%
# X_train_pp, y_train = preprocess_data(X_train, y_train, n_classes = n_classes) 
# X_valid_pp, y_valid = preprocess_data(X_valid, y_valid, n_classes = n_classes)
# X_test_pp , y_test  = preprocess_data(X_test, y_test, n_classes=n_classes)

# %% [markdown]
# ####  Examples of augmented images (without normalization)
#
# we skip normalization to produce image visualizations

# %%
data_gen_args = dict(rotation_range=20,
                     width_shift_range=0.2,
                     height_shift_range=0.2,
                     shear_range = 0.2,
                     zoom_range=0.2,
                     vertical_flip = False,
                     data_format = 'channels_last')
print(data_gen_args)
datagen = kp.image.ImageDataGenerator( **data_gen_args)
datagen.fit(X_train[img_lst])
datagen_flow = datagen.flow(X_train[img_lst], y_train[img_lst], batch_size=16, shuffle =False)
print(X_train[img_lst].shape)
# Out:
# {'rotation_range': 20, 'width_shift_range': 0.2, 'height_shift_range': 0.2, 'shear_range': 0.2, 'zoom_range': 0.2, 'vertical_flip': False, 'data_format': 'channels_last'}
# (16, 32, 32, 3)

# %%
X_batch , y_batch  = datagen_flow.next()

# %%
display_images(X_train[img_lst], y_train[img_lst], signnames,ticks = True, grid = False, h_pad = 0, w_pad = 1, shape=(4,8))

# %%
display_images(X_batch , y_batch , signnames,ticks = True, grid = False, h_pad = 0, w_pad = 1, shape=(4,8))

# %%
print(X_batch_demo.shape, y_img.shape)
X_aug_demo = X_train[0:1]
y_aug_demo = y_train[0:1] 
print(X_aug_demo.shape, y_aug_demo.shape)
X_aug_demo = np.concatenate((X_aug_demo,X_batch[0:1]))
y_aug_demo = np.concatenate((y_aug_demo,y_batch[0:1]))
print(X_aug_demo.shape, y_aug_demo.shape)

display_images(X_aug_demo, y_aug_demo, signnames,ticks = True, grid = False, h_pad = 0, w_pad = 1)
# Out:
# (30, 32, 32, 3) (30,)
# (1, 32, 32, 3) (1,)
# (2, 32, 32, 3) (2,)

# %%
for i in range(15):
    X_img, y_img = datagen_flow.next() 
    X_batch_demo = np.concatenate((X_batch_demo,X_img))
    y_batch_demo = np.concatenate((y_batch_demo,y_img))
    print(X_batch_demo.shape, y_batch_demo.shape)
# Out:
# (1, 32, 32, 3) (1,)
# (2, 32, 32, 3) (2,)
# (3, 32, 32, 3) (3,)
# (4, 32, 32, 3) (4,)
# (5, 32, 32, 3) (5,)
# (6, 32, 32, 3) (6,)
# (7, 32, 32, 3) (7,)
# (8, 32, 32, 3) (8,)
# (9, 32, 32, 3) (9,)
# (10, 32, 32, 3) (10,)
# (11, 32, 32, 3) (11,)
# (12, 32, 32, 3) (12,)
# (13, 32, 32, 3) (13,)
# (14, 32, 32, 3) (14,)
# (15, 32, 32, 3) (15,)
# (16, 32, 32, 3) (16,)

# %%
display_images(X_batch, y_batch, signnames,ticks = True, grid = False, h_pad = 0, w_pad = 1)

# %%
print(X_batch_demo.shape, y_batch_demo.shape)

X_img, y_img = datagen_flow.next() 
display_images(X_img, y_img, signnames,ticks = True, grid = False, h_pad = 0, w_pad = 1)
# Out:
# (16, 32, 32, 3) (16,)

# %%
del datagen

# %% [markdown]
# ### Define Model Architectures

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# #### This is equivalent to the model_config configuration file

# %% [markdown]
#     mdl_config['arch1'] = dict(
#                 ckpt_prefix = 'arch1',
#                 mu = 0 ,
#                 sigma = 0.1,
#                 f1_size = 5,
#                 f2_size = 5,
#                 l1_units = 6,
#                 l2_units = 16,
#                 fc1_units = 120,
#                 fc2_units = 120,
#                 fc3_units = 43,
#                 drop_rate = 0.0)
#
#     mdl_config['arch1_dropout'] = dict(
#                 ckpt_prefix =  'arch1_dropout',
#                 mu = 0,
#                 sigma = 0.1,
#                 f1_size = 5,
#                 f2_size = 5,
#                 l1_units = 6,
#                 l2_units = 16,
#                 fc1_units = 120,
#                 fc2_units = 120,
#                 fc3_units = 43,
#                 drop_rate = 0.5)
#
#     mdl_config['arch4'] = dict(
#                 ckpt_prefix = 'arch4',
#                 mu = 0 ,
#                 sigma = 0.1,
#                 f1_size = 5,
#                 f2_size = 5,
#                 l1_units = 16,
#                 l2_units = 16,
#                 fc1_units = 240,
#                 fc2_units = 240,
#                 fc3_units = 43,
#                 drop_rate = 0.0)

# %% [markdown]
# #### Architecture 1

# %% [markdown]
#         Key1   Key2      Epochs  BatchSize  Batches/Epoch    LR Epoch    Trn Acc[0]   Trn Acc[End]    Vld Acc[St]    Val Acc[End]
#      LR:0.001  BS:128       100        128           272       0.0010        0.2656        1.0000        0.2277        0.9522
#      LR:0.001  BS:16        100         16          2175       0.0010        0.3125        0.9375        0.1626        0.9163
#      LR:0.001  BS:256       100        256           136       0.0010        0.3984        1.0000        0.3372        0.9347
#      LR:0.001  BS:32        100         32          1088       0.0010        0.2812        1.0000        0.1694        0.9249
#      LR:0.001  BS:64        100         64           544       0.0010        0.2656        1.0000        0.2478        0.9354

# %% [markdown]
# #### Architecture 1 + Dropout

# %% [markdown]
#        Key1    Key2      Epochs  BatchSize  Batches/Epoch    LR Epoch    Trn Acc[0]   Trn Acc[End]    Vld Acc[St]    Val Acc[End]
#      LR:0.001  BS:128       100        128           272       0.0010        0.4141        1.0000        0.2850        0.9433
#      LR:0.001  BS:16        100         16          2175       0.0010        0.0000        1.0000        0.0864        0.9444
#      LR:0.001  BS:256       100        256           136       0.0010        0.3555        1.0000        0.2968        0.9238
#      LR:0.001  BS:32        100         32          1088       0.0010        0.1250        1.0000        0.1741        0.9356
#      LR:0.001  BS:64        100         64           544       0.0010        0.1719        1.0000        0.1968        0.9417

# %% [markdown]
# #### Architecture 2

# %% [markdown]
#        Key1    Key2      Epochs  BatchSize  Batches/Epoch    LR Epoch    Trn Acc[0]   Trn Acc[End]    Vld Acc[St]    Val Acc[End]
#      LR:0.001  BS:128       100        128           272       0.0010        0.5000        1.0000        0.4075        0.9522
#      LR:0.001  BS:256       100        256           136       0.0010        0.4961        1.0000        0.4848        0.9406
#      LR:0.001  BS:32        100         32          1088       0.0010        0.3125        1.0000        0.2050        0.9553
#      LR:0.001  BS:64        100         64           544       0.0010        0.2656        1.0000        0.2190        0.9542

# %% [markdown]
# #### Architecture 2 + Dropout

# %% [markdown]
#        Key1    Key2      Epochs  BatchSize  Batches/Epoch    LR Epoch    Trn Acc[0]   Trn Acc[End]    Vld Acc[St]    Val Acc[End]   Vld Loss[St]   Vld Loss[End]
#      LR:0.001  BS:128       100        128           272       0.0010        0.5000        1.0000        0.3789        0.9585        2.3972        0.5642
#      LR:0.001  BS:256       100        256           136       0.0010        0.5234        1.0000        0.4605        0.9519        1.9156        0.3735
#      LR:0.001  BS:32        100         32          1088       0.0010        0.3125        1.0000        0.2322        0.9247        3.0287        2.1800
#      LR:0.001  BS:512       100        512            68       0.0010        0.5762        1.0000        0.5585        0.9333        1.5748        0.5397
#      LR:0.001  BS:64        100         64           544       0.0010        0.3281        1.0000        0.2995        0.9413        2.6054        1.2703

# %% [markdown]
# #### Architecture 3

# %% [markdown]
#         Key1   Key2      Epochs  BatchSize  Batches/Epoch    LR Epoch    Trn Acc[0]   Trn Acc[End]    Vld Acc[St]    Val Acc[End]   Vld Loss[St]   Vld Loss[End]
#      LR:0.001  BS:128       100        128           272       0.0010        0.1641        1.0000        0.2036        0.9154        3.2231        0.8364
#      LR:0.001  BS:256       100        256           136       0.0010        0.3164        1.0000        0.3127        0.9433        2.8097        0.4450
#      LR:0.001  BS:32        100         32          1088       0.0010        0.1875        1.0000        0.1476        0.9224        3.3871        1.6040
#      LR:0.001  BS:512       100        512            68       0.0010        0.3535        1.0000        0.3052        0.9018        2.5797        0.7607
#      LR:0.001  BS:64        100         64           544       0.0010        0.1250        1.0000        0.1501        0.9324        3.3146        1.2503

# %% [markdown]
# #### Architecture 3 + Dropout

# %% [markdown]
#         Key1   Key2      Epochs  BatchSize  Batches/Epoch    LR Epoch    Trn Acc[0]   Trn Acc[End]    Vld Acc[St]    Val Acc[End]   Vld Loss[St]   Vld Loss[End]
#      LR:0.001  BS:128       100        128           272       0.0010        0.3438        1.0000        0.2451        0.9506        2.9201        0.4465
#      LR:0.001  BS:256       100        256           136       0.0010        0.2812        1.0000        0.2120        0.9254        3.1682        0.6320
#      LR:0.001  BS:32        100         32          1088       0.0010        0.0938        1.0000        0.1265        0.9245        3.4810        2.8498
#      LR:0.001  BS:512       100        512            68       0.0010        0.3691        1.0000        0.2769        0.9111        2.6104        0.7892
#      LR:0.001  BS:64        100         64           544       0.0010        0.1875        1.0000        0.1660        0.9410        3.2837        0.8721

# %% [markdown]
# #### Architecture A4

# %% [markdown]
# A4  is  basically A2  and  fc2_units from 120 to 240

# %% [markdown]
# #### Architecture A4 + Dropout + Image Augmentation

# %% [markdown]
#      Key1   Key2      Epochs  BatchSize  Batches/Epoch    LR Epoch    Trn Acc[0]   Trn Acc[End]    Vld Acc[St]    Val Acc[End]   Vld Loss[St]  Loss[End]
#      LR:0.001  BS:128       100        128           272       0.0010        0.5547        1.0000        0.5043        0.9499        1.8797        0.4712
#      LR:0.001  BS:256       100        256           136       0.0010        0.5234        1.0000        0.5091        0.9358        1.8166        0.6350
#      LR:0.001  BS:32        100         32          1088       0.0010        0.4062        1.0000        0.2823        0.9488        2.8727        4.4364
#      LR:0.001  BS:512       100        512            68       0.0010        0.6387        1.0000        0.5259        0.9265        1.5283        0.7469
#      LR:0.001  BS:64        100         64           544       0.0010        0.5312        1.0000        0.3478        0.9576        2.4057        1.6015

# %% [markdown]
# #### Architecture A4, A5, A6, A7

# %% [markdown]
# A4 Dropout is  basically A2+Dropout  and  fc2_units from 120 to 240
#
# A5 Dropout is  expansion of A4 in number of units in 1st hidden layer
#
# A6 Dropout is  expansion of A4 in number of units in 2nd hidden layer
#
# A7 Dropout is  expansion of A4 in number of units in 1st AND 2nd hidden layer

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.

from common.model import model, run_model_training, model_optimization, model_accuracy

# %% [markdown]
# ### Run Training

# %% [markdown]
# #### Setup Preprocessing Pipeline

# %%
# Remove the previous weights and bias
simple_gen_args = dict(featurewise_center=True,
                     featurewise_std_normalization = True,
                     data_format = 'channels_last')

data_gen_args = dict(featurewise_center=True,
                     featurewise_std_normalization = True,
                     rotation_range=10,
                     width_shift_range=0.2,
                     height_shift_range=0.2,
                     zoom_range=0.2,
                     vertical_flip = False,
                     data_format = 'channels_last')
print(data_gen_args)

trn_datagen = kp.image.ImageDataGenerator( **data_gen_args)
vld_datagen = kp.image.ImageDataGenerator( **data_gen_args)

# trn_datagen = kp.image.ImageDataGenerator( **simple_gen_args)
# vld_datagen = kp.image.ImageDataGenerator( **simple_gen_args)

trn_datagen.fit(X_train)
vld_datagen.fit(X_valid)

num_trn_examples = len(X_train)
num_val_examples = len(X_valid)

print()
ttl = ' Data Augmentation Parameters '
print(ttl)
print('','-'*len(ttl))
for i,v in data_gen_args.items():
    print(' {:.<35s} {}'.format(i,v) )
# Out:
# {'featurewise_center': True, 'featurewise_std_normalization': True, 'rotation_range': 10, 'width_shift_range': 0.2, 'height_shift_range': 0.2, 'zoom_range': 0.2, 'vertical_flip': False, 'data_format': 'channels_last'}
# (34799, 32, 32, 3) (4410, 32, 32, 3)

# %% [markdown]
# #### Display Number of Batches per Epoch (BPE) based on batch size

# %%
print(' Batch          Training          Validation  ')
print(' Size        Batches/Epoch      Batches/Epoch')
print('------       ---------------    ---------------')
for bs in  [512, 256, 128, 64, 32, 16]:
    trn_bpe = math.ceil(num_trn_examples/bs)
    val_bpe = math.ceil(num_val_examples/bs)
    print(' {:5d}    {:12d}    {:15d}  '.format(bs, trn_bpe,val_bpe))
# Out:
#  Batch          Training          Validation
#  Size        Batches/Epoch      Batches/Epoch
# ------       ---------------    ---------------
#    512              68                  9
#    256             136                 18
#    128             272                 35
#     64             544                 69
#     32            1088                138
#     16            2175                276

# %%
results = defaultdict(defaultdict)

# %% [markdown]
# #### Load `model_config.cfg` file

# %%
config_file = configparser.ConfigParser()
config_file.read('model_config.cfg')
print(' Model configurations: ', config_file.sections())
# Out:
#  Model configurations:  ['arch0', 'arch0_dropout', 'arch1', 'arch1_dropout', 'arch2', 'arch2_dropout', 'arch3', 'arch3_dropout', 'arch4', 'arch4_dropout', 'arch5', 'arch5_dropout', 'arch6', 'arch6_dropout', 'arch7', 'arch7_dropout', 'arch00', 'arch00_dropout']

# %% [markdown]
# #### Load Model Training Results file (to get model checkpoint file)

# %%
##-------------------------------------------------------------------------
## Model and Training parameters 
##-------------------------------------------------------------------------
# MODEL_ARCH = args.model_config
# BATCH_SIZES = args.batch_sizes     ## [256, 128, 64, 32, 16]
# TRAINING_SCHEDULE =  args.training_schedule 
# TRAINING_SCHEDULE = [(2, 0.001), (2, 0.0005), (2, 0.0002), (2, 0.0001)]
# TRAINING_SCHEDULE = [(100, 0.0002), (100, 0.0001)

# MODEL_ARCH  = 'arch5'
# BATCH_SIZES = [128,64,32]
# TRAINING_SCHEDULE = [(200, 0.001), (100, 0.0005), (100, 0.0002), (100, 0.0001)]

MODEL_ARCH = 'arch3_dropout'
BATCH_SIZES = [32]       ## [256, 128, 64, 32, 16]
TRAINING_SCHEDULE = [(200, 0.001), (100, 0.0005), (100, 0.0002), (100, 0.0001)]

results_filename = MODEL_ARCH+'_results_test'
results_dict     = MODEL_ARCH+'_results_test'

##----------------------------------------------------------------------
## Get model configuration parms
##----------------------------------------------------------------------
mdl_config = get_from_config(config_file, MODEL_ARCH)
print(mdl_config.keys())

print()
print(' MODEL_ARCH      : ' , MODEL_ARCH)
print()
ttl = ' {} Model parameters: '.format(MODEL_ARCH)
print(ttl)
print('','-'*len(ttl))
for i,v in mdl_config[MODEL_ARCH].items():
    print(' {:.<35s} {}'.format(i,v) )
    
##----------------------------------------------------------------------
## Determine whether we are continuing a previous training run
##----------------------------------------------------------------------
BS_KEY = 'BS:'+str(BATCH_SIZES [0])

reload = True

print()    
print(' Checkpt prefix  : ' , mdl_config[MODEL_ARCH]['ckpt_prefix'])
print(' Results Filename: ' , results_filename, '\t\t Results Dictionary Keyname:', results_dict)
print(' Reload flag     : ' , reload)
try:
    print(' last model ckpt: ', results[BS_KEY]['last_ckpt'])
    print(' last epoch ran : ', results[BS_KEY]['epochs'][-1])
except:
    print(' *** reload flag set to FALSE')
    reload = False
    
print(' Reload flag     : ', reload)
print(' Batch size key  : ', BS_KEY)
# Out:
#  Model configurations:  ['arch0', 'arch0_dropout', 'arch1', 'arch1_dropout', 'arch2', 'arch2_dropout', 'arch3', 'arch3_dropout', 'arch4', 'arch4_dropout', 'arch5', 'arch5_dropout', 'arch6', 'arch6_dropout', 'arch7', 'arch7_dropout', 'arch00', 'arch00_dropout']
#
#  MODEL_ARCH      :  arch3_dropout
#
#  arch3_dropout Model parameters:
#  ---------------------------------
#  l1_units........................... 16
#  l2_units........................... 16
#  fc1_units.......................... 120
#  fc2_units.......................... 240
#  drop_rate.......................... 0.5
#  mu................................. 0.0
#  sigma.............................. 0.1
#  f1_size............................ 5
#  f2_size............................ 5
#  fc3_units.......................... 43
#  ckpt_prefix........................ arch3_dropout
# dict_keys(['BS:128', 'BS:64', 'BS:32', 'BS:256'])
#
#  Checkpt prefix  :  arch3_dropout
# ...

# %% [markdown]
# #### `run_model_training()`

# %%
for BATCH_SIZE in BATCH_SIZES:

    BS_KEY = 'BS:'+str(BATCH_SIZE)
    reload = True
    print()
    print('\n Model Config  : ', MODEL_ARCH)
    print(' Checkpt prefix  : ', mdl_config[MODEL_ARCH]['ckpt_prefix'])
    print(' Results Filename: ', results_filename, '\t\t Results Dictionary Keyname:', results_dict)
    print(' Batch size key : ', BS_KEY)

    
    trn_datagen_flow = trn_datagen.flow(X_train, y_train, batch_size= BATCH_SIZE)
    vld_datagen_flow = vld_datagen.flow(X_valid, y_valid, batch_size= BATCH_SIZE)

    trn_bpe = math.ceil(num_trn_examples/ BATCH_SIZE)
    val_bpe = math.ceil(num_val_examples/ BATCH_SIZE)

    for EP,LR in TRAINING_SCHEDULE[0:]:
        
        reload = True
        print(' Batch size: ',  BATCH_SIZE, ' # Epochs: ', EP, ' Learning Rate: ', LR)
        
        if reload:
            try:
                load_ckpt = results[BS_KEY]['last_ckpt']
                print(' checkpoint to load: ', load_ckpt)
            except:
                print(' reload flag set to FALSE \n\n')
                reload = False
                load_ckpt = None
                results[BS_KEY] = defaultdict(list)
        
        run_model_training( trn_datagen_flow,
                            vld_datagen_flow, 
                            mdl_config[MODEL_ARCH],
                            results = results[BS_KEY],
                            epochs = EP, 
                            learning_rate = LR, 
                            batch_size = BATCH_SIZE, 
                            training_batches = trn_bpe, 
                            validation_batches = val_bpe, 
                            reload = reload,
                            ckpt_file = load_ckpt)

        save_results(results_filename, results, results_dict )
# Out:
#  Model Config  :  arch3_dropout
#  Checkpt prefix  :  arch3_dropout
#  Batch size key :  BS:32
#  Batch size:  32  # Epochs:  200  Learning Rate:  0.001
#  checkpoint to load:  ./checkpoints/arch3_dropout_bs32_ep495_dr0.5_201103160123
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-16d1f35b7cc6> in <module>
#      34                             learning_rate = LR,
#      35                             batch_size = BATCH_SIZE,
# ---> 36                             training_batches = trn_bpe,
#      37                             validation_batches = val_bpe,
#      38                             reload = reload,
#
# NameError: name 'trn_bpe' is not defined

# %% [markdown]
# #### inspect Results

# %%
#  save_results(results_filename, results, results_dict )
# Out:
# Saving data to pickle file...
# Data cached in pickle file. arch4_dropout_results_test.pickle

# %%
# import copy
# results = defaultdict()  
# results['BS:64'] = copy.copy(results1['BS:64'])
# # del results['BS:'+'128']
# print(results.keys())
# print(results['BS:64'].keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4f67b1d22b1f> in <module>
#       3 # results['BS:64'] = copy.copy(results1['BS:64'])
#       4 # # del results['BS:'+'128']
# ----> 5 print(results.keys())
#       6 # print(results['BS:64'].keys())
#
# NameError: name 'results' is not defined

# %%
# key = 'BS:32'
# print(len( results[key]['val_acc']))
# results[key]['run_ckpt_acc'] = []
# for ep,ck in zip(results[key]['run_epochs'], results[key]['run_ckpts']):
#     print(ep, '   ', results[key]['val_acc'][ep-1],'   ',ck)
#     results[key]['run_ckpt_acc'].append(results[key]['val_acc'][ep-1])

# del results['BS:128']

# from itertools import zip_longest
# key = 'BS:128'
# print(len( results[key]['val_acc']))
# for ep,ac, ck in zip_longest(results[key]['run_epochs'], results[key]['run_ckpt_acc'], results[key]['run_ckpts']):
#     if ac is None:
#         ac = '@@@'
#     print(' {:6d}     {:7.4f}     {} '.format(ep, ac,ck))
print(results.keys())
# Out:
# dict_keys(['BS:64', 'BS:32'])

# %%
# for k2 in results.keys():
#     print(' {:6s}   {:7.4f}    {}  '.format(k2, results[k2].get('best_val_acc', 'not found'), results[k2]['last_ckpt']))

# key = 'BS:32'
# print(key)
# print('-'*len(key) )
# for idx, (ep,ck,ac) in enumerate(zip(results[key]['run_epochs'], results[key]['run_ckpts'],results[key]['run_ckpt_acc']),1):
#         print(' {:4d}  {:6d}     {:7.4f}     {} '.format(idx, ep, ac,ck))

# print(len( test_results['BS:128']['val_acc']))
# # results['BS:128']['run_ckpt_acc'] = []

# for ep,ac, ck in zip(results['BS:128']['run_epochs'], results['BS:128']['val_acc'], results['BS:128']['run_ckpts']):
#     print(ep, '   ', ac,'   ',ck)
#     results['BS:128']['run_ckpt_acc'] = results['BS:128']['val_acc'][ep-1]

# %%
# del res_d['arch1_results_test2']
# print(' Dictionary name : ', res_d.keys())

#  save_results(results_filename, test_results, results_dict )

# display_training_results2( results, 'BS:64', verbose = True)

# display_training_results2(results, 'BS:128', verbose = True)
# Out:
#  Dictionary name :  dict_keys(['arch1_results_test'])

# %% [markdown]
# #### Training Results

# %%
import copy 
# load_key = 'arch1_dropout_results_test'
# load_key = 'arch7_V_dropout_results_test'
in_file  = 'arch0_results_test'
in_key   = 'arch0_results_test'
# out_file = 'arch0_results_test'
# out_key  = 'arch0_results_test'
res_d = load_results('./results/'+ in_file)
print(' Dictionary name : ', res_d.keys())
print(' Dictionary name : ', res_d[in_key].keys())
test_results = res_d[in_key]

# res_d['arch8_dropout_results_test'] = copy.copy(res_d['arch3_dropout_results_test'])
# print(test_results['BS:64'].keys())
# Out:
#  Dictionary name :  dict_keys(['arch0_results_test'])
#  Dictionary name :  dict_keys(['BS:64', 'BS:32', 'BS:128', 'BS:256'])

# %%
display_training_results(test_results ,  verbose = True)
# Out:
#                       Batch    Batches             Best          Training                           Validation
#   Key2      Epochs    Size     /Epochs     LR      VAcc     Acc[St]     Acc[End]    Loss[St]   Loss[End]    Acc[St]     Acc[End]
#  BS:32        500       32      1088   0.00010    0.9069     0.6000      1.0000      1.6567      0.9477      0.5098      0.9060
#  BS:64        500       64       544   0.00010    0.9267     0.5745      0.9787      1.8329      0.7543      0.4686      0.9159
#  BS:128       500      128       272   0.00010    0.9321     0.6000      0.9375      1.7074      0.7033      0.5098      0.9071
#  BS:256       500      256       136   0.00010    0.9201     0.1875      0.9375      3.0464      0.5849      0.1667      0.8438

# %%
# display_training_results2(test_results , 64, verbose = True)

# %%
test_results.keys()
# Out:
# dict_keys(['BS:64', 'BS:32', 'BS:128', 'BS:256'])

# %%
plot_training_results(test_results, rolling_window = 10)

# %%
plot_training_results_by_batchsize(test_results, rolling_window = 20)

# %% [markdown]
# ### Run Test

# %%
from common.model import run_model_inference
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# #### Setup Test Dataset Preprocessing data flow

# %%
# Remove the previous weights and bias
test_gen_args = dict(featurewise_center=True,
                     featurewise_std_normalization = True,
                     data_format = 'channels_last' )

test_datagen = kp.image.ImageDataGenerator( **test_gen_args)
test_datagen.fit(X_test)

num_test_examples = len(X_test)

print()
ttl = ' Data Augmentation Parameters '
print(ttl)
print('','-'*len(ttl))
for i,v in test_gen_args.items():
    print(' {:.<35s} {}'.format(i,v) )
    
print(' {:.<37s} {}'.format('\n Num test examples',num_test_examples) )
# Out:
#  Data Augmentation Parameters
#  ------------------------------
#  featurewise_center................. True
#  featurewise_std_normalization...... True
#  data_format........................ channels_last
#
#  Num test examples.................. 12630

# %% [markdown]
# #### Setup Test Pipeline

# %%
MODEL_ARCH = 'arch3_dropout'
TRAINING_BATCH_SIZES = [32,64,128,256]       ## [256, 128, 64, 32, 16]
TEST_BATCH_SIZE = 1263
##----------------------------------------------------------------------
## Get model configuration parms
##----------------------------------------------------------------------
mdl_config = get_from_config('model_config.cfg', MODEL_ARCH)
print()
print(' MODEL_ARCH      : ' , MODEL_ARCH)
print()
ttl = ' {} Model parameters: '.format(MODEL_ARCH)
print(ttl)
print('','-'*len(ttl))
for i,v in mdl_config[MODEL_ARCH].items():
    print('    {:.<35s} {}'.format(i,v) )


##----------------------------------------------------------------------
## Load Training run results file for Checkpoint file to load
##----------------------------------------------------------------------
results_dir      = './results/'
results_filename = MODEL_ARCH+'_results'
results_dict = load_results(results_dir+results_filename)
if results_dict != -1:
    load_key = list(results_dict.keys())[0]
    results = results_dict[load_key]
    print(results.keys())
else:
    print('\n ERROR: Results file not found!!!')
    

##----------------------------------------------------------------------
## Setup results file to save testing results 
##----------------------------------------------------------------------
inference_results_filename = MODEL_ARCH+'_test_results'
inference_results_dict     = MODEL_ARCH+'_test_results'
inference_results = defaultdict(dict)    
    
##----------------------------------------------------------------------
## Check if a valid model checkpoint exists to load
##----------------------------------------------------------------------
reload = True
print()    
# print(' BS Key          : ', BS_KEY)
print(' Checkpt prefix  : ', mdl_config[MODEL_ARCH]['ckpt_prefix'])
print(' Results Filename: ', results_filename)
print(' Results Dict Key: ', load_key)
print(' Reload flag     : ', reload)
print()
for bs in [32,64,128,256]:
    BS_KEY = 'BS:'+str(bs)
    try:
        load_file = results[BS_KEY]['last_ckpt']
    except:
        print('',BS_KEY,' *** ERROR: Checkpoint file not found')
    else:    
        print('',BS_KEY,' Checkpoint file found ')
        print('',BS_KEY,' last model ckpt : ', load_file)
# Out:
#  Model configurations:  ['arch0', 'arch0_dropout', 'arch1', 'arch1_dropout', 'arch2', 'arch2_dropout', 'arch3', 'arch3_dropout', 'arch4', 'arch4_dropout', 'arch5', 'arch5_dropout', 'arch6', 'arch6_dropout', 'arch7', 'arch7_dropout', 'arch00', 'arch00_dropout']
#
#  MODEL_ARCH      :  arch3_dropout
#
#  arch3_dropout Model parameters:
#  ---------------------------------
#     l1_units........................... 16
#     l2_units........................... 16
#     fc1_units.......................... 120
#     fc2_units.......................... 240
#     drop_rate.......................... 0.5
#     mu................................. 0.0
#     sigma.............................. 0.1
#     f1_size............................ 5
#     f2_size............................ 5
#     fc3_units.......................... 43
#     ckpt_prefix........................ arch3_dropout
# dict_keys(['BS:128', 'BS:64', 'BS:32', 'BS:256'])
#
#  Checkpt prefix  :  arch3_dropout
# ...

# %%
# for BATCH_SIZE in TRAINING_BATCH_SIZES:
for BATCH_SIZE in [128]:
    BS_KEY = 'BS:'+str(BATCH_SIZE)
    test_datagen_flow = test_datagen.flow(X_test, y_test, batch_size= TEST_BATCH_SIZE, shuffle = False)
    test_bpe = math.ceil(num_test_examples/ TEST_BATCH_SIZE)
    inference_results[BS_KEY] = defaultdict(list)

    try:
        load_ckpt = results[BS_KEY]['last_ckpt']
    except:
        print(' *** ERROR: Checkpoint file not found')
        break

    
    print(' Model Config       : ', MODEL_ARCH)
    print(' Training BS Key    : ', BS_KEY)    
    print(' Model checkpoint   : ', load_ckpt)
    print(' Results Filename   : ', results_filename)
#     print(' Batch size key  : ', BS_KEY)
    print(' Testing Batch size : ', TEST_BATCH_SIZE, 'Batches per epoch: ' , test_bpe) 
    print('\n')

        
    y_pred, y_true = run_model_inference( test_datagen_flow,
                        mdl_config[MODEL_ARCH],
                        results = inference_results[BS_KEY],                                            
                        epochs = 1, 
                        batch_size = TEST_BATCH_SIZE, 
                        inference_batches = test_bpe, 
                        ckpt_file = load_ckpt)
    print(len(y_pred), len(y_true))
    y_pred = np.vstack(y_pred)
    y_true = np.vstack(y_true)
    print(y_pred.shape, y_true.shape)
#     inference_results.append(results)
suffix = '_'+datetime.now().strftime("%y%m%d%H%M%S")
output_file = results_dir+inference_results_filename+suffix
save_results(output_file, inference_results, inference_results_dict )
# Out:
#  Model Config       :  arch3_dropout
#  Training BS Key    :  BS:128
#  Model checkpoint   :  ./checkpoints/arch3_dropout_bs128_ep442_dr0.5_201103051550
#  Results Filename   :  arch3_dropout_results
#  Testing Batch size :  1263 Batches per epoch:  10
#
#
#  layer  layer1  after conv2d :  Tensor("Conv2D:0", shape=(?, 28, 28, 16), dtype=float32)
#  layer  layer1  after bias add :  Tensor("BiasAdd:0", shape=(?, 28, 28, 16), dtype=float32)
#  layer  layer1  type:  RELU  after activation :  Tensor("layer1:0", shape=(?, 28, 28, 16), dtype=float32)
#  layer  maxpool1  after max pooling :  Tensor("maxpool1:0", shape=(?, 14, 14, 16), dtype=float32)
#  layer  layer2  after conv2d :  Tensor("Conv2D_1:0", shape=(?, 10, 10, 16), dtype=float32)
#  layer  layer2  after bias add :  Tensor("BiasAdd_1:0", shape=(?, 10, 10, 16), dtype=float32)
#  layer  layer2  type:  RELU  after activation :  Tensor("layer2:0", shape=(?, 10, 10, 16), dtype=float32)
# ...

# %%
print("[INFO] evaluating network...")
print(classification_report(y_true.argmax(axis=1), y_pred.argmax(axis=1), target_names=signnames_list))
# Out:
# [INFO] evaluating network...
#                                    precision    recall  f1-score   support
#
#            0-Speed limit (20km/h)       0.98      0.70      0.82        60
#            1-Speed limit (30km/h)       0.97      1.00      0.98       720
#            2-Speed limit (50km/h)       0.95      0.98      0.97       750
#            3-Speed limit (60km/h)       0.98      0.97      0.97       450
#            4-Speed limit (70km/h)       0.95      0.98      0.97       660
#            5-Speed limit (80km/h)       0.96      0.93      0.94       630
#     6-End of speed limit (80km/h)       0.91      0.93      0.92       150
#           7-Speed limit (100km/h)       0.98      0.96      0.97       450
#           8-Speed limit (120km/h)       0.97      0.98      0.98       450
#                      9-No passing       0.98      0.96      0.97       480
# 10-No passing for vehicles over 3       0.99      0.99      0.99       660
# ...

# %%
cm = confusion_matrix(y_true.argmax(axis=1), y_pred.argmax(axis=1))
cmd = ConfusionMatrixDisplay(cm)
print(cmd)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(17,17))
cmd.plot(ax = ax)

# %%
print(inference_results.keys())
print(inference_results['BS:128'].keys())
pp.pprint(inference_results['BS:128'])
# Out:
# dict_keys(['BS:128', 'BS:32'])
# dict_keys(['bpe', 'batch_size', 'epochs', 'batches', 'test_acc', 'model_file', 'run_epochs'])
# defaultdict(<class 'list'>,
#             { 'batch_size': 1263,
#               'batches': [10],
#               'bpe': 10,
#               'epochs': [1],
#               'model_file': './checkpoints/arch3_dropout_bs128_ep442_dr0.5_201103051550',
#               'run_epochs': [1],
#               'test_acc': [0.9501979351043701]})

# %%
from common.utils import display_inference_results
display_inference_results(inference_results, verbose = True)
# Out:
#                       Batch    Batches      Inference
#   Key2      Epochs    Size     /Epoch       Accuracy      Weights File
#  BS:32          1     1263        10         0.9385       ./checkpoints/arch3_dropout_bs32_ep495_dr0.5_201103160123
#  BS:64          1     1263        10         0.9410       ./checkpoints/arch3_dropout_bs64_ep421_dr0.5_201103093235
#  BS:128         1     1263        10         0.9502       ./checkpoints/arch3_dropout_bs128_ep442_dr0.5_201103051550
#  BS:256         1     1263        10         0.9496       ./checkpoints/arch3_dropout_bs256_ep470_dr0.5_201104004834

# %% [markdown]
# ## Step 3: Test a Model on New Images

# %% [markdown]
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
### Run the predictions here and use the model to output the prediction for each image.
### Make sure to pre-process the images with the same pre-processing pipeline used earlier.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tf.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.

# %% [markdown]
# ## Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ## Step 4 (Optional): Visualize the Neural Network's State with Test Images

# %% [markdown]
# ---
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it may be having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")
